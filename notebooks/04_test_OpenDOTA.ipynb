# %%
import requests
import pandas as pd

# Define the API endpoint
API_URL = "https://api.opendota.com/api/publicMatches"

# Define query parameters (adjust as needed)
params = {
    "min_rank": 50,  # Legend Rank minimum
    "max_rank": 65,  # Ancient Rank maximum
    "mmr_descending": 1  # Order by highest MMR first
}

# Make the API request
response = requests.get(API_URL, params=params)

# Check if the request was successful
if response.status_code == 200:
    matches = response.json()
    
    # Convert to DataFrame for better readability
    df = pd.DataFrame(matches)
    
    # Display the first few rows
    print(df.head())
    
else:
    print(f"Error: {response.status_code}", response.text)
# Out:
#      match_id  match_seq_num  radiant_win  start_time  duration  lobby_type  \
# 0  8164517013     6863031800        False  1739003507      2620           7
# 1  8164557705     6863057677         True  1739005948      2047           7
# 2  8164478002     6863021758        False  1739001007      4372           7
# 3  8164515015     6863020838         True  1739003382      1932           7
# 4  8164540116     6863042858        False  1739004883      2034           7
#
#    game_mode  avg_rank_tier  num_rank_tier  cluster            radiant_team  \
# 0         22             65              6      186   [135, 93, 74, 14, 64]
# 1         22             65              4      271     [34, 4, 2, 74, 111]
# 2         22             65              5      118   [25, 100, 49, 26, 64]
# 3         22             65              2      227  [35, 108, 62, 14, 145]
# 4         22             65              4      187    [121, 4, 39, 97, 74]
#
#                dire_team
# 0  [54, 102, 19, 30, 62]
# 1  [135, 76, 31, 94, 71]
# 2    [31, 94, 15, 5, 39]
# 3   [2, 114, 31, 88, 85]
# 4  [31, 38, 54, 102, 25]

# %%
df
# Out:
#       match_id  match_seq_num  radiant_win  start_time  duration  lobby_type  \
# 0   8164517013     6863031800        False  1739003507      2620           7
# 1   8164557705     6863057677         True  1739005948      2047           7
# 2   8164478002     6863021758        False  1739001007      4372           7
# 3   8164515015     6863020838         True  1739003382      1932           7
# 4   8164540116     6863042858        False  1739004883      2034           7
# ..         ...            ...          ...         ...       ...         ...
# 95  8164433209     6862949057        False  1738997887      1610           7
# 96  8164428205     6862962648         True  1738997517      3144           7
# 97  8164518919     6863019622         True  1739003627      1580           7
# 98  8164561304     6863063284        False  1739006148      2250           7
# 99  8164560914     6863045832         True  1739006122      1039           7
#
#     game_mode  avg_rank_tier  num_rank_tier  cluster            radiant_team  \
# 0          22             65              6      186   [135, 93, 74, 14, 64]
# 1          22             65              4      271     [34, 4, 2, 74, 111]
# 2          22             65              5      118   [25, 100, 49, 26, 64]
# 3          22             65              2      227  [35, 108, 62, 14, 145]
# 4          22             65              4      187    [121, 4, 39, 97, 74]
# ..        ...            ...            ...      ...                     ...
# 95         22             65              3      181    [44, 62, 79, 16, 17]
# 96         22             65              2      121   [86, 30, 67, 13, 108]
# 97         22             65              3      182    [94, 64, 36, 58, 70]
# 98         22             65              3      153  [137, 10, 67, 74, 135]
# 99         22             65              3      153    [25, 45, 135, 4, 75]
#
#                 dire_team
# 0   [54, 102, 19, 30, 62]
# 1   [135, 76, 31, 94, 71]
# 2     [31, 94, 15, 5, 39]
# 3    [2, 114, 31, 88, 85]
# 4   [31, 38, 54, 102, 25]
# ..                    ...
# 95   [74, 10, 60, 51, 99]
# 96    [58, 62, 19, 6, 26]
# 97   [47, 86, 44, 25, 98]
# 98  [104, 25, 31, 44, 88]
# 99    [39, 7, 36, 40, 93]
#
# [100 rows x 12 columns]
